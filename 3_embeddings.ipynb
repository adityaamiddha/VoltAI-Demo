# %%
# !pip -q install sentence-transformers tqdm
# !pip install tf-keras
# Out:
# Collecting tf-keras
#   Downloading tf_keras-2.20.1-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: tensorflow<2.21,>=2.20 in /Users/adityaamiddha/hello/.conda/lib/python3.11/site-packages (from tf-keras) (2.20.0)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/adityaamiddha/hello/.conda/lib/python3.11/site-packages (from tensorflow<2.21,>=2.20->tf-keras) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/adityaamiddha/hello/.conda/lib/python3.11/site-packages (from tensorflow<2.21,>=2.20->tf-keras) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /Users/adityaamiddha/hello/.conda/lib/python3.11/site-packages (from tensorflow<2.21,>=2.20->tf-keras) (25.9.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /Users/adityaamiddha/hello/.conda/lib/python3.11/site-packages (from tensorflow<2.21,>=2.20->tf-keras) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in /Users/adityaamiddha/hello/.conda/lib/python3.11/site-packages (from tensorflow<2.21,>=2.20->tf-keras) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /Users/adityaamiddha/hello/.conda/lib/python3.11/site-packages (from tensorflow<2.21,>=2.20->tf-keras) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in /Users/adityaamiddha/hello/.conda/lib/python3.11/site-packages (from tensorflow<2.21,>=2.20->tf-keras) (3.4.0)
# Requirement already satisfied: packaging in /Users/adityaamiddha/hello/.conda/lib/python3.11/site-packages (from tensorflow<2.21,>=2.20->tf-keras) (25.0)
# Requirement already satisfied: protobuf>=5.28.0 in /Users/adityaamiddha/hello/.conda/lib/python3.11/site-packages (from tensorflow<2.21,>=2.20->tf-keras) (6.33.2)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/adityaamiddha/hello/.conda/lib/python3.11/site-packages (from tensorflow<2.21,>=2.20->tf-keras) (2.32.5)
# Requirement already satisfied: setuptools in /Users/adityaamiddha/hello/.conda/lib/python3.11/site-packages (from tensorflow<2.21,>=2.20->tf-keras) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /Users/adityaamiddha/hello/.conda/lib/python3.11/site-packages (from tensorflow<2.21,>=2.20->tf-keras) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/adityaamiddha/hello/.conda/lib/python3.11/site-packages (from tensorflow<2.21,>=2.20->tf-keras) (3.2.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in /Users/adityaamiddha/hello/.conda/lib/python3.11/site-packages (from tensorflow<2.21,>=2.20->tf-keras) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /Users/adityaamiddha/hello/.conda/lib/python3.11/site-packages (from tensorflow<2.21,>=2.20->tf-keras) (2.0.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/adityaamiddha/hello/.conda/lib/python3.11/site-packages (from tensorflow<2.21,>=2.20->tf-keras) (1.76.0)
# Requirement already satisfied: tensorboard~=2.20.0 in /Users/adityaamiddha/hello/.conda/lib/python3.11/site-packages (from tensorflow<2.21,>=2.20->tf-keras) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in /Users/adityaamiddha/hello/.conda/lib/python3.11/site-packages (from tensorflow<2.21,>=2.20->tf-keras) (3.12.0)
# Requirement already satisfied: numpy>=1.26.0 in /Users/adityaamiddha/hello/.conda/lib/python3.11/site-packages (from tensorflow<2.21,>=2.20->tf-keras) (2.3.5)
# Requirement already satisfied: h5py>=3.11.0 in /Users/adityaamiddha/hello/.conda/lib/python3.11/site-packages (from tensorflow<2.21,>=2.20->tf-keras) (3.15.1)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in /Users/adityaamiddha/hello/.conda/lib/python3.11/site-packages (from tensorflow<2.21,>=2.20->tf-keras) (0.5.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/adityaamiddha/hello/.conda/lib/python3.11/site-packages (from astunparse>=1.6.0->tensorflow<2.21,>=2.20->tf-keras) (0.44.0)
# Requirement already satisfied: rich in /Users/adityaamiddha/hello/.conda/lib/python3.11/site-packages (from keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (14.2.0)
# Requirement already satisfied: namex in /Users/adityaamiddha/hello/.conda/lib/python3.11/site-packages (from keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (0.1.0)
# Requirement already satisfied: optree in /Users/adityaamiddha/hello/.conda/lib/python3.11/site-packages (from keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (0.18.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/adityaamiddha/hello/.conda/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow<2.21,>=2.20->tf-keras) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/adityaamiddha/hello/.conda/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow<2.21,>=2.20->tf-keras) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/adityaamiddha/hello/.conda/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow<2.21,>=2.20->tf-keras) (2.6.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/adityaamiddha/hello/.conda/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow<2.21,>=2.20->tf-keras) (2025.11.12)
# Requirement already satisfied: markdown>=2.6.8 in /Users/adityaamiddha/hello/.conda/lib/python3.11/site-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras) (3.10)
# Requirement already satisfied: pillow in /Users/adityaamiddha/hello/.conda/lib/python3.11/site-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras) (12.0.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/adityaamiddha/hello/.conda/lib/python3.11/site-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/adityaamiddha/hello/.conda/lib/python3.11/site-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras) (3.1.4)
# Requirement already satisfied: markupsafe>=2.1.1 in /Users/adityaamiddha/hello/.conda/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/adityaamiddha/hello/.conda/lib/python3.11/site-packages (from rich->keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/adityaamiddha/hello/.conda/lib/python3.11/site-packages (from rich->keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /Users/adityaamiddha/hello/.conda/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (0.1.2)
# Downloading tf_keras-2.20.1-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 4.7 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: tf-keras
# Successfully installed tf-keras-2.20.1

# %%
from pathlib import Path
import json
from tqdm import tqdm

CHUNK_FILE = Path("data/chunks/iea_ev_outlook_chunks.jsonl")
OUT_DIR = Path("data/embeddings")
OUT_DIR.mkdir(parents=True, exist_ok=True)

OUT_FILE = OUT_DIR / "iea_ev_outlook_embeddings_local.jsonl"
assert CHUNK_FILE.exists(), "Chunk file not found."

chunks = []
with CHUNK_FILE.open("r", encoding="utf-8") as f:
    for line in f:
        chunks.append(json.loads(line))

print("✅ Loaded chunks:", len(chunks))
# Out:
# ✅ Loaded chunks: 352

# %%
from sentence_transformers import SentenceTransformer

MODEL_NAME = "BAAI/bge-small-en-v1.5"   # excellent + fast
model = SentenceTransformer(MODEL_NAME)
print("✅ Loaded embedding model:", MODEL_NAME)
# Out:
# ✅ Loaded embedding model: BAAI/bge-small-en-v1.5

# %%
def load_done_ids(out_file: Path):
    done = set()
    if not out_file.exists():
        return done
    with out_file.open("r", encoding="utf-8") as f:
        for line in f:
            obj = json.loads(line)
            done.add(obj["chunk_id"])
    return done

done_ids = load_done_ids(OUT_FILE)
print("Already embedded:", len(done_ids))

count_new = 0

with OUT_FILE.open("a", encoding="utf-8") as out_f:
    for obj in tqdm(chunks, desc="Embedding chunks (local)"):
        chunk_id = obj["chunk_id"]
        if chunk_id in done_ids:
            continue
        
        text = obj["text"]
        emb = model.encode(text, normalize_embeddings=True).tolist()

        out_record = {
            "chunk_id": chunk_id,
            "source": obj["source"],
            "year": obj["year"],
            "domain": obj["domain"],
            "text": text,
            "embedding": emb
        }

        out_f.write(json.dumps(out_record, ensure_ascii=False) + "\n")
        count_new += 1

print("✅ New embeddings created:", count_new)
print("✅ Output file:", OUT_FILE)
# Out:
# Already embedded: 0
# Embedding chunks (local): 100%|██████████| 352/352 [00:14<00:00, 23.54it/s]
# ✅ New embeddings created: 352
# ✅ Output file: data/embeddings/iea_ev_outlook_embeddings_local.jsonl

# %%
import json

n = 0
dim = None
with OUT_FILE.open("r", encoding="utf-8") as f:
    for line in f:
        obj = json.loads(line)
        n += 1
        if dim is None:
            dim = len(obj["embedding"])

print("✅ Total vectors:", n)
print("✅ Embedding dimension:", dim)
# Out:
# ✅ Total vectors: 352
# ✅ Embedding dimension: 384
